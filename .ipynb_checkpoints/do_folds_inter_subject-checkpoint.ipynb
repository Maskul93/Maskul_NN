# %%
import csv
from random import shuffle
import os

total_patients = 26
num_folds = 10
patients_test = 5

out_sub_folder = "folds_test"

random_assignment = True


subjects_path = "../All_csv_subjects/Subjects_Windows_csv/"
log = subjects_path + out_sub_folder + "/folds_info.txt"
if not os.path.exists(subjects_path + out_sub_folder):
    os.mkdir(subjects_path + out_sub_folder)

with open(log, 'w') as f_log: 

    for n in range(1,num_folds+1):
        train_file = subjects_path + out_sub_folder + "/TrainFold_" + str(n) + ".csv"
        test_file_learned = subjects_path + out_sub_folder + "/TestFold_L_" + str(n) + ".csv"
        test_file_unlearned = subjects_path + out_sub_folder + "/TestFold_U_" + str(n) + ".csv"

        if random_assignment:
            l = [i for i in range(1,total_patients+1)]
            shuffle(l)
            l_test = l[:patients_test]
            l_train = l[patients_test:]
        else:
            l_test = []
            for i in range((n-1)*patients_test +1,(n-1)*patients_test + patients_test+1):
                if (i<=total_patients):
                    l_test.append(i)
            l_train = []
            for i in range(1,total_patients+1):
                if not i in l_test:
                    l_train.append(i)
                    
        print("Fold: " + str(n))    
        print("Train: " + str(l_train))
        print("Test: " + str(l_test))
        
        
        with open(train_file, mode='w') as t_out:
            csv_writer = csv.writer(t_out, delimiter=',')
            with open(test_file_learned, mode='w') as t_out_test:
                csv_writer_test = csv.writer(t_out_test, delimiter=',')
                f_log.write("Subjects in Train Fold " + str(n) + ": " + str(l[5:]) + "\n") 
                for i in l_train:
                    with open(subjects_path + f_name + str(i) +'.csv', mode='r') as s_in:
                        csv_reader = csv.reader(s_in, delimiter=',')
                        row_count = sum(1 for row in csv_reader)
                    train_count = int(row_count*0.9)
                    print("Rows: " + str(row_count))
                    print("Train rows:" + str(train_count))
                    count = 0
                    with open(subjects_path + f_name + str(i) +'.csv', mode='r') as s_in:
                        csv_reader = csv.reader(s_in, delimiter=',')
                        for line in csv_reader:
                            count += 1
                            if (count<train_count):
                                csv_writer.writerow(line)
                            else:
                                csv_writer_test.writerow(line)
        with open(test_file_unlearned, mode='w') as t_out:
            csv_writer = csv.writer(t_out, delimiter=',')
            f_log.write("Subjects in Test Fold " + str(n) + ": " + str(l[:5])+ "\n\n") 
            for i in l_test:
                with open(subjects_path + f_name + str(i) +'.csv', mode='r') as s_in:
                    csv_reader = csv.reader(s_in, delimiter=',')
                    for line in csv_reader:
                        csv_writer.writerow(line)
        print("Fold " + str(n) + " node!")
# Out:
# Fold: 1
# Train: [23, 11, 8, 17, 19, 9, 24, 4, 18, 1, 10, 5, 22, 3, 12, 6, 25, 26, 21, 7, 20]
# Test: [15, 16, 13, 14, 2]
# Rows: 13890
# Train rows:12501
# Rows: 24139
# Train rows:21725
# Rows: 24152
# Train rows:21736
# Rows: 24132
# Train rows:21718
# Rows: 24126
# Train rows:21713
# Rows: 24139
# Train rows:21725
# Rows: 13884
# Train rows:12495
# Rows: 24148
# Train rows:21733
# Rows: 24102
# Train rows:21691
# Rows: 24155
# Train rows:21739
# Rows: 24139
# Train rows:21725
# Rows: 24142
# Train rows:21727
# Rows: 13860
# Train rows:12474
# Rows: 24176
# Train rows:21758
# Rows: 24110
# Train rows:21699
# Rows: 24122
# Train rows:21709
# Rows: 13883
# Train rows:12494
# Rows: 13884
# Train rows:12495
# Rows: 24147
# Train rows:21732
# Rows: 24150
# Train rows:21735
# Rows: 24135
# Train rows:21721
# Fold 1 node!
# Fold: 2
# Train: [25, 17, 18, 23, 6, 4, 15, 10, 20, 2, 19, 3, 8, 11, 5, 22, 9, 26, 14, 16, 12]
# Test: [21, 7, 13, 24, 1]
# Rows: 13883
# Train rows:12494
# Rows: 24132
# Train rows:21718
# Rows: 24102
# Train rows:21691
# Rows: 13890
# Train rows:12501
# Rows: 24122
# Train rows:21709
# Rows: 24148
# Train rows:21733
# Rows: 24111
# Train rows:21699
# Rows: 24139
# Train rows:21725
# Rows: 24135
# Train rows:21721
# Rows: 24164
# Train rows:21747
# Rows: 24126
# Train rows:21713
# Rows: 24176
# Train rows:21758
# Rows: 24152
# Train rows:21736
# Rows: 24139
# Train rows:21725
# Rows: 24142
# Train rows:21727
# Rows: 13860
# Train rows:12474
# Rows: 24139
# Train rows:21725
# Rows: 13884
# Train rows:12495
# Rows: 24133
# Train rows:21719
# Rows: 24115
# Train rows:21703
# Rows: 24110
# Train rows:21699
# Fold 2 node!
# Fold: 3
# Train: [7, 19, 23, 16, 6, 14, 3, 17, 11, 18, 20, 25, 26, 1, 24, 12, 5, 10, 22, 4, 8]
# Test: [13, 21, 9, 15, 2]
# Rows: 24150
# Train rows:21735
# Rows: 24126
# Train rows:21713
# Rows: 13890
# Train rows:12501
# Rows: 24115
# Train rows:21703
# Rows: 24122
# Train rows:21709
# Rows: 24133
# Train rows:21719
# Rows: 24176
# Train rows:21758
# Rows: 24132
# Train rows:21718
# Rows: 24139
# Train rows:21725
# Rows: 24102
# Train rows:21691
# Rows: 24135
# Train rows:21721
# Rows: 13883
# Train rows:12494
# Rows: 13884
# Train rows:12495
# Rows: 24155
# Train rows:21739
# Rows: 13884
# Train rows:12495
# Rows: 24110
# Train rows:21699
# Rows: 24142
# Train rows:21727
# Rows: 24139
# Train rows:21725
# Rows: 13860
# Train rows:12474
# Rows: 24148
# Train rows:21733
# Rows: 24152
# Train rows:21736
# Fold 3 node!
# Fold: 4
# Train: [22, 21, 25, 20, 12, 26, 14, 4, 18, 2, 6, 1, 13, 3, 5, 8, 24, 16, 9, 23, 7]
# Test: [19, 10, 11, 15, 17]
# Rows: 13860
# Train rows:12474
# Rows: 24147
# Train rows:21732
# Rows: 13883
# Train rows:12494
# Rows: 24135
# Train rows:21721
# Rows: 24110
# Train rows:21699
# Rows: 13884
# Train rows:12495
# Rows: 24133
# Train rows:21719
# Rows: 24148
# Train rows:21733
# Rows: 24102
# Train rows:21691
# Rows: 24164
# Train rows:21747
# Rows: 24122
# Train rows:21709
# Rows: 24155
# Train rows:21739
# Rows: 24105
# Train rows:21694
# Rows: 24176
# Train rows:21758
# Rows: 24142
# Train rows:21727
# Rows: 24152
# Train rows:21736
# Rows: 13884
# Train rows:12495
# Rows: 24115
# Train rows:21703
# Rows: 24139
# Train rows:21725
# Rows: 13890
# Train rows:12501
# Rows: 24150
# Train rows:21735
# Fold 4 node!
# Fold: 5
# Train: [16, 17, 9, 25, 4, 10, 23, 6, 13, 3, 5, 2, 18, 19, 26, 24, 21, 1, 14, 12, 8]
# Test: [11, 20, 15, 7, 22]
# Rows: 24115
# Train rows:21703
# Rows: 24132
# Train rows:21718
# Rows: 24139
# Train rows:21725
# Rows: 13883
# Train rows:12494
# Rows: 24148
# Train rows:21733
# Rows: 24139
# Train rows:21725
# Rows: 13890
# Train rows:12501
# Rows: 24122
# Train rows:21709
# Rows: 24105
# Train rows:21694
# Rows: 24176
# Train rows:21758
# Rows: 24142
# Train rows:21727
# Rows: 24164
# Train rows:21747
# Rows: 24102
# Train rows:21691
# Rows: 24126
# Train rows:21713
# Rows: 13884
# Train rows:12495
# Rows: 13884
# Train rows:12495
# Rows: 24147
# Train rows:21732
# Rows: 24155
# Train rows:21739
# Rows: 24133
# Train rows:21719
# Rows: 24110
# Train rows:21699
# Rows: 24152
# Train rows:21736
# Fold 5 node!
# Fold: 6
# Train: [12, 6, 5, 25, 15, 3, 9, 23, 21, 24, 17, 7, 2, 8, 4, 22, 19, 16, 10, 11, 1]
# Test: [14, 26, 18, 13, 20]
# Rows: 24110
# Train rows:21699
# Rows: 24122
# Train rows:21709
# Rows: 24142
# Train rows:21727
# Rows: 13883
# Train rows:12494
# Rows: 24111
# Train rows:21699
# Rows: 24176
# Train rows:21758
# Rows: 24139
# Train rows:21725
# Rows: 13890
# Train rows:12501
# Rows: 24147
# Train rows:21732
# Rows: 13884
# Train rows:12495
# Rows: 24132
# Train rows:21718
# Rows: 24150
# Train rows:21735
# Rows: 24164
# Train rows:21747
# Rows: 24152
# Train rows:21736
# Rows: 24148
# Train rows:21733
# Rows: 13860
# Train rows:12474
# Rows: 24126
# Train rows:21713
# Rows: 24115
# Train rows:21703
# Rows: 24139
# Train rows:21725
# Rows: 24139
# Train rows:21725
# Rows: 24155
# Train rows:21739
# Fold 6 node!
# Fold: 7
# Train: [19, 4, 7, 3, 5, 2, 24, 11, 10, 13, 22, 14, 12, 21, 16, 20, 9, 15, 17, 6, 25]
# Test: [8, 18, 23, 26, 1]
# Rows: 24126
# Train rows:21713
# Rows: 24148
# Train rows:21733
# Rows: 24150
# Train rows:21735
# Rows: 24176
# Train rows:21758
# Rows: 24142
# Train rows:21727
# Rows: 24164
# Train rows:21747
# Rows: 13884
# Train rows:12495
# Rows: 24139
# Train rows:21725
# Rows: 24139
# Train rows:21725
# Rows: 24105
# Train rows:21694
# Rows: 13860
# Train rows:12474
# Rows: 24133
# Train rows:21719
# Rows: 24110
# Train rows:21699
# Rows: 24147
# Train rows:21732
# Rows: 24115
# Train rows:21703
# Rows: 24135
# Train rows:21721
# Rows: 24139
# Train rows:21725
# Rows: 24111
# Train rows:21699
# Rows: 24132
# Train rows:21718
# Rows: 24122
# Train rows:21709
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-c2904d97e7b7> in <module>()
#      68                             count += 1
#      69                             if (count<train_count):
# ---> 70                                 csv_writer.writerow(line)
#      71                             else:
#      72                                 csv_writer_test.writerow(line)
#
# KeyboardInterrupt:

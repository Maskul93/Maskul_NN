# %%
## -- Extract Real Baographic
# This function simply saves onto a file the original basographic signal

import csv
import statistics
import pandas as pd
import os

in_path = "../subjects/min-max/"
out_path = "../subjects/min-max/Real_Baographics/"
prefix = 'Biphase_Subject'
suffix = '_norm'
out_prefix = "Original_Basographic_"
#create folders if not existing...
if not os.path.exists(out_path):
    os.makedirs(out_path)
    
first_subj = 1
end_subj = 1

label_column = 10    # Column of the label in the original .csv

for subj in range(first_subj, end_subj+1):
    ## -- Mi serve per eliminare tutto fino al primo Swing (il primo 1)
    csv_swing = []
    found = False    # Flag per stoppare il ciclo quando trova il primo Swing
    with open(in_path + prefix + str(subj) + suffix + '.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        swing_onset = 0
        for line in csv_reader: 
            if not found:
                csv_swing.append(line)
                swing_onset += 1
                if line[label_column] == '1.000000':
                    found = True
    print('Swing Onset at sample ' + str(swing_onset))
    
    ## -- Lo converto in dataframe
    csv_in = []
    with open(in_path + prefix + str(subj) + suffix + '.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        for line in csv_reader:
            csv_in.append(line)
        print("L'ho letto!")
    
    limit = len(csv_in)
    
    complete = pd.DataFrame(csv_in)
    complete = complete.iloc[:,-1]
    
    #baso_signal = []
    #for row in csv_in:
     #   baso_signal.append(csv_in[-1])
        
#print(baso_signal[1:10])    
    
   
    
    #csv_out = []
   
    with open(out_path + out_prefix + "s" + str(subj) + ".csv", mode = 'w') as csv_out_file:
        csv_writer = csv.writer(csv_out_file, delimiter=',')
        for line in range(swing_onset + 1, limit):
            csv_writer.writerow(complete[line])
# Out:
# Swing Onset at sample 6348
# L'ho letto!

# %%
complete
# Out:
# 0         0.000000
# 1         0.000000
# 2         0.000000
# 3         0.000000
# 4         0.000000
# 5         0.000000
# 6         0.000000
# 7         0.000000
# 8         0.000000
# 9         0.000000
# 10        0.000000
# 11        0.000000
# 12        0.000000
# 13        0.000000
# 14        0.000000
# 15        0.000000
# 16        0.000000
# 17        0.000000
# 18        0.000000
# 19        0.000000
# 20        0.000000
# 21        0.000000
# 22        0.000000
# 23        0.000000
# 24        0.000000
# 25        0.000000
# 26        0.000000
# 27        0.000000
# 28        0.000000
# 29        0.000000
#             ...
# 486570    0.000000
# 486571    0.000000
# 486572    0.000000
# 486573    0.000000
# 486574    0.000000
# 486575    0.000000
# 486576    0.000000
# 486577    0.000000
# 486578    0.000000
# 486579    0.000000
# 486580    0.000000
# 486581    0.000000
# 486582    0.000000
# 486583    0.000000
# 486584    0.000000
# 486585    0.000000
# 486586    0.000000
# 486587    0.000000
# 486588    0.000000
# 486589    0.000000
# 486590    0.000000
# 486591    0.000000
# 486592    0.000000
# 486593    0.000000
# 486594    0.000000
# 486595    0.000000
# 486596    0.000000
# 486597    0.000000
# 486598    0.000000
# 486599    0.000000
# Name: 10, Length: 486600, dtype: object

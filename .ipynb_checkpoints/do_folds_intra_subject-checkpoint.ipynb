# %%
import csv
from random import shuffle
import os

total_patients = 10
n_folds = 10

random_assignment = True

subjects_path = "./min-max/windows_20/tr-True_sliding_20_c-False/"
prefix = "s"
suffix = "_norm_windows_20.csv"
out_sub_folder = "folds"

log = subjects_path + out_sub_folder + "/folds_info.txt"

if not os.path.exists(subjects_path + out_sub_folder):
    os.mkdir(subjects_path + out_sub_folder)


for subj in range(1,total_patients+1):
    subj_lines = []
    with open(subjects_path + prefix + str(subj) + suffix, mode='r') as csv_file:
        csv_reader = csv.reader(csv_file)
        for line in csv_reader:
            subj_lines.append(line)
    
    out_path = subjects_path + out_sub_folder + "/subject" + str(subj)
    if not os.path.exists(out_path):
        os.mkdir(out_path)
    
    n_lines = len(subj_lines)
    print("Subject " + str(subj) + " lines: " + str(n_lines))
    
    pace = int(n_lines/n_folds)
    fold = 0
    for startTest in range(0,n_lines - pace + 1,pace):    
        fold += 1                               
        endTest = startTest + pace
        print("TestSet selected: from line " + str(startTest) + " to " + str(endTest) + '.')
        with open(out_path + "/TrainFold" + str(fold) + ".csv", mode='w') as train_file:
            csv_writer_train = csv.writer(train_file)
            for line in subj_lines[:startTest]:
                csv_writer_train.writerow(line)
            for line in subj_lines[endTest:]:
                csv_writer_train.writerow(line)
        with open(out_path + "/TestFold" + str(fold) + ".csv", mode='w') as test_file:
            csv_writer_test = csv.writer(test_file)
            for line in subj_lines[startTest:endTest]:
                csv_writer_test.writerow(line)
# Out:
# Subject 1 lines: 31150
# TestSet selected: from line 0 to 3115.
# TestSet selected: from line 3115 to 6230.
# TestSet selected: from line 6230 to 9345.
# TestSet selected: from line 9345 to 12460.
# TestSet selected: from line 12460 to 15575.
# TestSet selected: from line 15575 to 18690.
# TestSet selected: from line 18690 to 21805.
# TestSet selected: from line 21805 to 24920.
# TestSet selected: from line 24920 to 28035.
# TestSet selected: from line 28035 to 31150.
# Subject 2 lines: 31344
# TestSet selected: from line 0 to 3134.
# TestSet selected: from line 3134 to 6268.
# TestSet selected: from line 6268 to 9402.
# TestSet selected: from line 9402 to 12536.
# TestSet selected: from line 12536 to 15670.
# TestSet selected: from line 15670 to 18804.
# TestSet selected: from line 18804 to 21938.
# TestSet selected: from line 21938 to 25072.
# TestSet selected: from line 25072 to 28206.
# TestSet selected: from line 28206 to 31340.
# Subject 3 lines: 26658
# TestSet selected: from line 0 to 2665.
# TestSet selected: from line 2665 to 5330.
# TestSet selected: from line 5330 to 7995.
# TestSet selected: from line 7995 to 10660.
# TestSet selected: from line 10660 to 13325.
# TestSet selected: from line 13325 to 15990.
# TestSet selected: from line 15990 to 18655.
# TestSet selected: from line 18655 to 21320.
# TestSet selected: from line 21320 to 23985.
# TestSet selected: from line 23985 to 26650.
# Subject 4 lines: 27642
# TestSet selected: from line 0 to 2764.
# TestSet selected: from line 2764 to 5528.
# TestSet selected: from line 5528 to 8292.
# TestSet selected: from line 8292 to 11056.
# TestSet selected: from line 11056 to 13820.
# TestSet selected: from line 13820 to 16584.
# TestSet selected: from line 16584 to 19348.
# TestSet selected: from line 19348 to 22112.
# TestSet selected: from line 22112 to 24876.
# TestSet selected: from line 24876 to 27640.
# Subject 5 lines: 26012
# TestSet selected: from line 0 to 2601.
# TestSet selected: from line 2601 to 5202.
# TestSet selected: from line 5202 to 7803.
# TestSet selected: from line 7803 to 10404.
# TestSet selected: from line 10404 to 13005.
# TestSet selected: from line 13005 to 15606.
# TestSet selected: from line 15606 to 18207.
# TestSet selected: from line 18207 to 20808.
# TestSet selected: from line 20808 to 23409.
# TestSet selected: from line 23409 to 26010.
# Subject 6 lines: 38010
# TestSet selected: from line 0 to 3801.
# TestSet selected: from line 3801 to 7602.
# TestSet selected: from line 7602 to 11403.
# TestSet selected: from line 11403 to 15204.
# TestSet selected: from line 15204 to 19005.
# TestSet selected: from line 19005 to 22806.
# TestSet selected: from line 22806 to 26607.
# TestSet selected: from line 26607 to 30408.
# TestSet selected: from line 30408 to 34209.
# TestSet selected: from line 34209 to 38010.
# Subject 7 lines: 25580
# TestSet selected: from line 0 to 2558.
# TestSet selected: from line 2558 to 5116.
# TestSet selected: from line 5116 to 7674.
# TestSet selected: from line 7674 to 10232.
# TestSet selected: from line 10232 to 12790.
# TestSet selected: from line 12790 to 15348.
# TestSet selected: from line 15348 to 17906.
# TestSet selected: from line 17906 to 20464.
# TestSet selected: from line 20464 to 23022.
# TestSet selected: from line 23022 to 25580.
# Subject 8 lines: 27264
# TestSet selected: from line 0 to 2726.
# TestSet selected: from line 2726 to 5452.
# TestSet selected: from line 5452 to 8178.
# TestSet selected: from line 8178 to 10904.
# TestSet selected: from line 10904 to 13630.
# TestSet selected: from line 13630 to 16356.
# TestSet selected: from line 16356 to 19082.
# TestSet selected: from line 19082 to 21808.
# TestSet selected: from line 21808 to 24534.
# TestSet selected: from line 24534 to 27260.
# Subject 9 lines: 29700
# TestSet selected: from line 0 to 2970.
# TestSet selected: from line 2970 to 5940.
# TestSet selected: from line 5940 to 8910.
# TestSet selected: from line 8910 to 11880.
# TestSet selected: from line 11880 to 14850.
# TestSet selected: from line 14850 to 17820.
# TestSet selected: from line 17820 to 20790.
# TestSet selected: from line 20790 to 23760.
# TestSet selected: from line 23760 to 26730.
# TestSet selected: from line 26730 to 29700.
# Subject 10 lines: 28278
# TestSet selected: from line 0 to 2827.
# TestSet selected: from line 2827 to 5654.
# TestSet selected: from line 5654 to 8481.
# TestSet selected: from line 8481 to 11308.
# TestSet selected: from line 11308 to 14135.
# TestSet selected: from line 14135 to 16962.
# TestSet selected: from line 16962 to 19789.
# TestSet selected: from line 19789 to 22616.
# TestSet selected: from line 22616 to 25443.
# TestSet selected: from line 25443 to 28270.
